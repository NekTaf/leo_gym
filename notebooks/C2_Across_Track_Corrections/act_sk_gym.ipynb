# %%
import numpy as np

# %%
from leo_gym.gyms.roe_sk_gym import RoeGym
from train_act_sk_cfg import env_cfg


env = RoeGym(cfg=env_cfg, seed=23)

# %%
from stable_baselines3.ppo import PPO

agent = PPO.load("policies/ppo_mdp_act_sk.zip")
# Out:
# c:\Users\vikto\anaconda3\envs\leo_gym\Lib\site-packages\stable_baselines3\common\save_util.py:167: UserWarning: Could not deserialize object clip_range. Consider using `custom_objects` argument to replace this object.
# Exception: code() argument 13 must be str, not int
#   warnings.warn(
# c:\Users\vikto\anaconda3\envs\leo_gym\Lib\site-packages\stable_baselines3\common\save_util.py:167: UserWarning: Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: code() argument 13 must be str, not int
#   warnings.warn(

# %%
try: 
    
    obs, _ = env.reset()
    
    while True:
        
        action,_ = agent.predict(obs)
        obs, rewards, TERMINATED, TRUNCATED, info = env.step(action)
        # print(action)
        
        if TERMINATED:
            break
                                                        
except KeyboardInterrupt:
    pass

sat1 = env.sat1

# %%
# sat1.plot_states_interactive()

# %%
sat1.plot_states_act()
